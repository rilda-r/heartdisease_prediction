# %%
import zipfile
zip_path = "heartdisease_dataset.zip"
with zipfile.ZipFile(zip_path,'r') as zip_ref:
  zip_ref.extractall("data")
print("Dataset extracted successfully")
# Out:
# Dataset extracted successfully

# %%
import os
os.listdir("heart_data")
# Out:
# ['heart.csv']

# %%
import pandas as pd
df=pd.read_csv("heart_data/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# sex: 0-female 1-male
# cp - chestpain type
# trestbps - resting bp
# thalach - max heart rate achieved
# oldpeak - ST depression induced by extercise relative to rest

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# age, sex, cp, trestbps, chol, fbs, thalach, exang, oldpeak

# %%
selected_features = [
    'age',
    'sex',
    'cp',
    'trestbps',
    'chol',
    'fbs',
    'thalach',
    'exang',
    'oldpeak'
]

X = df[selected_features]
y = df['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test=train_test_split(
    X,y,
    test_size=0.25,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (768, 9)
# (257, 9)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
print("Model accuracy:", accuracy)
# Out:
# Model accuracy: 0.9883268482490273

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[132   0]
#  [  3 122]]

# %%
sample_patient = [[
    55,   # age
    1,    # sex
    3,    # chest pain
    140,  # bp
    250,  # cholesterol
    0,    # fasting sugar
    150,  # max heart rate
    1,    # exercise angina
    2.3   # oldpeak
]]

prediction = model.predict(sample_patient)

print("Prediction:", "Heart Disease" if prediction[0] == 1 else "No Heart Disease")
# Out:
# Prediction: No Heart Disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

sample_patient = pd.DataFrame([{
    'age': 55,
    'sex': 1,
    'cp': 3,
    'trestbps': 140,
    'chol': 250,
    'fbs': 0,
    'thalach': 150,
    'exang': 1,
    'oldpeak': 2.3
}])

prediction = model.predict(sample_patient)

print("Prediction:", "Heart Disease" if prediction[0] == 1 else "No Heart Disease")
# Out:
# Prediction: No Heart Disease

# %%
import pickle
with open("heartdisease_rfmodel.pkl","wb") as file:
  pickle.dump(model,file)

# %%
from google.colab import files
files.download('/content/heartdisease_rfmodel.pkl')
